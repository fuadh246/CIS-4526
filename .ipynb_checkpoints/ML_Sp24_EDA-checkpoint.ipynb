# %% [markdown]
# ## CIS 4526 Sp24 EDA Review Exercise

# %% [markdown]
# ### This Review Exercise will cover the following skills set
# * Using sql
# * Checking for null values and outliers
# * Calculate simple statistics using both SQL and Pandas
# * Calculate skew and correlation
# * Basic Data Visualization
# * How to fix missing values

# %% [markdown]
# **Make sure you have pandasql installed. If not, make sure you run the code in the following cell**

# %%
import os
try:
    import pandasql as ps
except:
    print("Failed in import pandasql")
    os.system("pip install pandasql")

# %% [markdown]
# **Import all standard libaries**

# %%
import pandas as pd
import pandasql as ps
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading Car Crashes dataset ##

# %%
crash = pd.read_csv("data/car_crashes2.csv")
print(crash.shape)
crash.head()
# Out:
# (52, 10)
#    accidents  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0       18.8     7.332    5.640          18.048       15.040       784.55
# 1       18.1     7.421    4.525          16.290       17.014      1053.48
# 2       18.6     6.510    5.208          15.624       17.856       899.47
# 3       22.4     4.032    5.824          21.056       21.280       827.34
# 4       12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses state region            division
# 0      145.08    AL  South  East South Central
# 1      133.93    AK   West             Pacific
# 2      110.35    AZ   West            Mountain
# 3      142.39    AR  South  West South Central
# 4      165.63    CA   West             Pacific

# %% [markdown]
# * accidents is the total number of crashes for each state
# * speeding is the average speeding in each state

# %%
crash.describe()
# Out:
#        accidents   speeding    alcohol  not_distracted  no_previous  \
# count  52.000000  51.000000  52.000000       52.000000    52.000000
# mean   15.817308   5.060235   5.574385       13.648154    14.043558
# std     4.086070   2.033018   5.245624        4.497172     3.737999
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.775000   3.766500   3.897000       10.611000    11.434000
# 50%    15.650000   4.806000   4.629000       13.908000    14.141500
# 75%    18.450000   6.531000   5.640500       16.334500    16.719500
# max    23.900000   9.450000  40.642000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    52.000000   52.000000
# mean    887.323654  134.865577
# std     176.559356   24.737451
# min     641.960000   82.750000
# 25%     768.690000  114.732500
# 50%     860.075000  136.590000
# 75%    1006.347500  152.335000
# max    1301.520000  194.780000

# %% [markdown]
# ## Question 1. Check if there are any null or NA

# %% [markdown]
# **Type in your code here**

# %%
crash.isnull().any()
# Out:
# accidents         False
# speeding           True
# alcohol           False
# not_distracted    False
# no_previous       False
# ins_premium       False
# ins_losses        False
# state             False
# region            False
# division          False
# dtype: bool

# %% [markdown]
# ## Question 2. Remove any rows that has null or NA

# %% [markdown]
# **Type in your code here**

# %%
crash[crash['speeding'].isnull()]
# Out:
#     accidents  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 32       12.3       NaN    3.567          10.824         9.84      1234.31
#
#     ins_losses state     region         division
# 32      150.01    NY  Northeast  Middle Atlantic

# %%
crash = crash.dropna()
crash.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 0 to 51
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   accidents       51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   state           51 non-null     object
#  8   region          51 non-null     object
#  9   division        51 non-null     object
# dtypes: float64(7), object(3)
# memory usage: 4.4+ KB

# %% [markdown]
# ## Question 3. Check if there is any outliers in all numerical fields using both scatter and boxplot

# %% [markdown]
# **Type in your code here**

# %%
crash.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 0 to 51
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   accidents       51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   state           51 non-null     object
#  8   region          51 non-null     object
#  9   division        51 non-null     object
# dtypes: float64(7), object(3)
# memory usage: 4.4+ KB

# %%
numerical_cols = crash.select_dtypes(exclude='object').columns

for col in numerical_cols:
    sns.scatterplot(data=crash, x='accidents', y=col,hue=col)
    plt.title(f'Scatter Plot of {col}')
    plt.show()
    sns.boxplot(data=crash[col])
    plt.title(f'Box Plot of {col}')
    plt.show()

# %% [markdown]
# ## Question 4. Display and Remove (the real) outliers

# %% [markdown]
# **Type in your code here**

# %%
crash = crash.drop(crash[crash['alcohol'] >= 30].index)
sns.scatterplot(x=crash['accidents'], y=crash['alcohol'])
crash
# Out:
#     accidents  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0        18.8     7.332    5.640          18.048       15.040       784.55
# 1        18.1     7.421    4.525          16.290       17.014      1053.48
# 2        18.6     6.510    5.208          15.624       17.856       899.47
# 3        22.4     4.032    5.824          21.056       21.280       827.34
# 4        12.0     4.200    3.360          10.920       10.680       878.41
# 5        13.6     5.032    3.808          10.744       12.920       835.50
# 6        10.8     4.968    3.888           9.396        8.856      1068.73
# 7        16.2     6.156    4.860          14.094       16.038      1137.87
# 8         5.9     2.006    1.593           5.900        5.900      1273.89
# 9        17.9     3.759    5.191          16.468       16.826      1160.13
# 10       15.6     2.964    3.900          14.820       14.508       913.15
# 11       17.5     9.450    7.175          14.350       15.225       861.18
# 12       15.3     5.508    4.437          13.005       14.994       641.96
# 13       12.8     4.608    4.352          12.032       12.288       803.11
# 14       14.5     3.625    4.205          13.775       13.775       710.46
# 15       15.7     2.669    3.925          15.229       13.659       649.06
# 16       17.8     4.806    4.272          13.706       15.130       780.45
# 17       21.4     4.066    4.922          16.692       16.264       872.51
# 18       20.5     7.175    6.765          14.965       20.090      1281.55
# 19       15.1     5.738    4.530          13.137       12.684       661.88
# 20       12.5     4.250    4.000           8.875       12.375      1048.78
# 21        8.2     1.886    2.870           7.134        6.560      1011.14
# 22       14.1     3.384    3.948          13.395       10.857      1110.61
# 23        9.6     2.208    2.784           8.448        8.448       777.18
# 24       17.6     2.640    5.456           1.760       17.600       896.07
# 25       16.1     6.923    5.474          14.812       13.524       790.32
# 26       21.4     8.346    9.416          17.976       18.190       816.21
# 27       14.9     1.937    5.215          13.857       13.410       732.28
# 28       14.7     5.439    4.704          13.965       14.553      1029.87
# 29       11.6     4.060    3.480          10.092        9.628       746.54
# 30       11.2     1.792    3.136           9.632        8.736      1301.52
# 31       18.4     3.496    4.968          12.328       18.032       869.85
# 33       16.8     6.552    5.208          15.792       13.608       708.24
# 34       23.9     5.497   10.038          23.661       20.554       688.75
# 35       14.1     3.948    4.794          13.959       11.562       697.73
# 36       19.9     6.368    5.771          18.308       18.706       881.51
# 37       12.8     4.224    3.328           8.576       11.520       804.71
# 38       18.2     9.100    5.642          17.472       16.016       905.99
# 40       11.1     3.774    4.218          10.212        8.769      1148.99
# 41       23.9     9.082    9.799          22.944       19.359       858.97
# 42       19.4     6.014    6.402          19.012       16.684       669.31
# 43       19.5     4.095    5.655          15.990       15.795       767.91
# 44       19.4     7.760    7.372          17.654       16.878      1004.75
# 45       11.3     4.859    1.808           9.944       10.848       809.38
# 46       13.6     4.080    4.080          13.056       12.920       716.20
# 47       12.7     2.413    3.429          11.049       11.176       768.95
# 48       10.6     4.452    3.498           8.692        9.116       890.03
# 49       23.8     8.092    6.664          23.086       20.706       992.61
# 50       13.8     4.968    4.554           5.382       11.592       670.31
# 51       17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses state     region            division
# 0       145.08    AL      South  East South Central
# 1       133.93    AK       West             Pacific
# 2       110.35    AZ       West            Mountain
# 3       142.39    AR      South  West South Central
# 4       165.63    CA       West             Pacific
# 5       139.91    CO       West            Mountain
# 6       167.02    CT  Northeast         New England
# 7       151.48    DE      South      South Atlantic
# 8       136.05    DC      South      South Atlantic
# 9       144.18    FL      South      South Atlantic
# 10      142.80    GA      South      South Atlantic
# 11      120.92    HI       West             Pacific
# 12       82.75    ID       West            Mountain
# 13      139.15    IL    Midwest  East North Central
# 14      108.92    IN    Midwest  East North Central
# 15      114.47    IA    Midwest  West North Central
# 16      133.80    KS    Midwest  West North Central
# 17      137.13    KY      South  East South Central
# 18      194.78    LA      South  West South Central
# 19       96.57    ME  Northeast         New England
# 20      192.70    MD      South      South Atlantic
# 21      135.63    MA  Northeast         New England
# 22      152.26    MI    Midwest  East North Central
# 23      133.35    MN    Midwest  West North Central
# 24      155.77    MS      South  East South Central
# 25      144.45    MO    Midwest  West North Central
# 26       85.15    MT       West            Mountain
# 27      114.82    NE    Midwest  West North Central
# 28      138.71    NV       West            Mountain
# 29      120.21    NH  Northeast         New England
# 30      159.85    NJ  Northeast     Middle Atlantic
# 31      120.75    NM       West            Mountain
# 33      127.82    NC      South      South Atlantic
# 34      109.72    ND    Midwest  West North Central
# 35      133.52    OH    Midwest  East North Central
# 36      178.86    OK      South  West South Central
# 37      104.61    OR       West             Pacific
# 38      153.86    PA  Northeast     Middle Atlantic
# 40      148.58    RI  Northeast         New England
# 41      116.29    SC      South      South Atlantic
# 42       96.87    SD    Midwest  West North Central
# 43      155.57    TN      South  East South Central
# 44      156.83    TX      South  West South Central
# 45      109.48    UT       West            Mountain
# 46      109.61    VT  Northeast         New England
# 47      153.72    VA      South      South Atlantic
# 48      111.62    WA       West             Pacific
# 49      152.56    WV      South      South Atlantic
# 50      106.62    WI    Midwest  East North Central
# 51      122.04    WY       West            Mountain

# %%
crash.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 0 to 51
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   accidents       50 non-null     float64
#  1   speeding        50 non-null     float64
#  2   alcohol         50 non-null     float64
#  3   not_distracted  50 non-null     float64
#  4   no_previous     50 non-null     float64
#  5   ins_premium     50 non-null     float64
#  6   ins_losses      50 non-null     float64
#  7   state           50 non-null     object
#  8   region          50 non-null     object
#  9   division        50 non-null     object
# dtypes: float64(7), object(3)
# memory usage: 4.3+ KB

# %% [markdown]
# ## Question 5. Calculate the average speeding in usa and Northeast region using SQL

# %% [markdown]
# **Type in your code here**

# %%
sql = 'select region, count(*), avg(speeding) from crash group by region where region is northeast'
ps.sqldf(sql)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~/anaconda3/lib/python3.10/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# OperationalError: near "where": syntax error
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandasql/sqldf.py:61, in PandaSQL.__call__(self, query, env)
#      60 try:
# ---> 61     result = read_sql(query, conn)
#      62 except DatabaseError as ex:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/sql.py:663, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     662 else:
# --> 663     return pandas_sql.read_query(
#     664         sql,
#     665         index_col=index_col,
#     666         params=params,
#     667         coerce_float=coerce_float,
#     668         parse_dates=parse_dates,
#     669         chunksize=chunksize,
#     670         dtype_backend=dtype_backend,
#     671         dtype=dtype,
#     672     )
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/sql.py:1738, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1692 """
#    1693 Read SQL query into a DataFrame.
#    1694
#    (...)
#    1736
#    1737 """
# -> 1738 result = self.execute(sql, params)
#    1739 columns = result.keys()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/sql.py:1562, in SQLDatabase.execute(self, sql, params)
#    1561 if isinstance(sql, str):
# -> 1562     return self.con.exec_driver_sql(sql, *args)
#    1563 return self.con.execute(sql, *args)
#
# File ~/anaconda3/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1686, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1684 args_10style, kwargs_10style = _distill_params_20(parameters)
# -> 1686 return self._exec_driver_sql(
#    1687     statement,
#    1688     args_10style,
#    1689     kwargs_10style,
#    1690     execution_options,
#    1691     future=True,
#    1692 )
#
# File ~/anaconda3/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1595, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1594 dialect = self.dialect
# -> 1595 ret = self._execute_context(
#    1596     dialect,
#    1597     dialect.execution_ctx_cls._init_statement,
#    1598     statement,
#    1599     distilled_parameters,
#    1600     execution_options,
#    1601     statement,
#    1602     distilled_parameters,
#    1603 )
#    1605 if not future:
#
# File ~/anaconda3/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File ~/anaconda3/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#
# File ~/anaconda3/lib/python3.10/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#
# File ~/anaconda3/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~/anaconda3/lib/python3.10/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# OperationalError: (sqlite3.OperationalError) near "where": syntax error
# [SQL: select region, count(*), avg(speeding) from crash group by region where region is Northeast]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# PandaSQLException                         Traceback (most recent call last)
# Cell In[68], line 2
#       1 sql = 'select region, count(*), avg(speeding) from crash group by region where region is Northeast'
# ----> 2 ps.sqldf(sql)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandasql/sqldf.py:156, in sqldf(query, env, db_uri)
#     124 def sqldf(query, env=None, db_uri='sqlite:///:memory:'):
#     125     """
#     126     Query pandas data frames using sql syntax
#     127     This function is meant for backward compatibility only. New users are encouraged to use the PandaSQL class.
#    (...)
#     154     >>> sqldf("select avg(x) from df;", locals())
#     155     """
# --> 156     return PandaSQL(db_uri)(query, env)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandasql/sqldf.py:63, in PandaSQL.__call__(self, query, env)
#      61     result = read_sql(query, conn)
#      62 except DatabaseError as ex:
# ---> 63     raise PandaSQLException(ex)
#      64 except ResourceClosedError:
#      65     # query returns nothing
#      66     result = None
#
# PandaSQLException: (sqlite3.OperationalError) near "where": syntax error
# [SQL: select region, count(*), avg(speeding) from crash group by region where region is Northeast]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ## Question 6. Calculate the average alcohol for each region using SQL

# %% [markdown]
# **Type in your code here**

# %% [markdown]
# ## Question 7. Calculate the number of occurrences, mean, min, max of the speeding for each divison using SQL

# %% [markdown]
# **Type in your code here**

# %% [markdown]
# ## Question 8. Answer Question 7 but use Pandas functions

# %% [markdown]
# **Type in your code here**

# %% [markdown]
# ## Question 9. Calculate the Standard deviation, Skew and Kurtosis for the accidents, speeding, alcohol for each region. Based on the results, describe any insights that you may have on the dataset ?

# %% [markdown]
# **Type in your code here**

# %% [markdown]
# ## Question 10. Plot the histogram of accidents distribution for different region using 5 bins

# %% [markdown]
# **Type in your answer here**

# %% [markdown]
# ### Now Load a different dataset (MPG dataset number 3)

# %%
mpg = pd.read_csv("data/mpg3.csv")
print(mpg.shape)
mpg.head()

# %% [markdown]
# # Question 11: Check to see if there are any missing values. Fix the missing values by imputing value from the mean.

# %% [markdown]
# ### Type your code here to fix the missing values by imputing value from the mean
